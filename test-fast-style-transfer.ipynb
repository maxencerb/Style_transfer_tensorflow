# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
content_path = "./content_images/champs_elysees.jpg"
style_path = "./style_images/starry_night.jpg"

# %%
from setup import load_img
from visualization import imshow

# %%
content_image = load_img(content_path)
style_image = load_img(style_path)

# %%
plt.subplot(1, 2, 1)
imshow(content_image, 'Content image')

plt.subplot(1, 2, 2)
imshow(style_image, 'Style image')

# %%
from fast_style_transfer import fast_style_transfer

# %%
image = fast_style_transfer(content_image, style_image)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x384 at 0x2E9E235EDF0>

# %%
image.save('results/champs_elysees_starry_night.png')
